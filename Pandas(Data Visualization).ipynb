# %%
import numpy as np
import pandas as pd
import seaborn as sns                # to make plots look good

# %%
df1=pd.read_csv("C:\\Users\\Puneet Sood\\Desktop\\Datascience_notes\\Unzipped files\\07-Pandas-Built-in-Data-Viz\\df1",index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv("C:\\Users\\Puneet Sood\\Desktop\\Datascience_notes\\Unzipped files\\07-Pandas-Built-in-Data-Viz\\df2")

df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1["A"].hist()

# %%
df1["A"].plot(kind="hist")                       #method1

# %%
df1["A"].plot.hist()                         #method2

# %%
df2.plot.area(alpha=0.4)                       #alpha transpirancy

# %%
df2.plot.bar(stacked =True)

# %%
df1.plot.line(y="B",figsize=(10,3))

# %%
df1.plot.scatter(x="A",y="B",c="D",cmap="coolwarm")            # c used as a third dimension

# %%
r=pd.DataFrame(np.random.randn(1000,2),columns=["A","B"])
r.head()
# Out:
#           A         B
# 0  1.283108 -1.117263
# 1 -0.103944  1.494644
# 2 -2.070147  1.937372
# 3  0.376997 -1.757784
# 4  1.564039  1.155492

# %%
r.plot.hexbin(x="A",y="B",gridsize=30,figsize=(7,5))
